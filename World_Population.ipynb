# %% [markdown]
# <a href="https://colab.research.google.com/github/GOWRISHANKARK80/World-Population-Data/blob/main/World_Population.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/world_population.csv")

# %%
pd.set_option("display.max_row",None)

# %%
df
# Out:
#      Rank CCA3                 Country/Territory              Capital  \
# 0      36  AFG                       Afghanistan                Kabul
# 1     138  ALB                           Albania               Tirana
# 2      34  DZA                           Algeria              Algiers
# 3     213  ASM                    American Samoa            Pago Pago
# 4     203  AND                           Andorra     Andorra la Vella
# 5      42  AGO                            Angola               Luanda
# 6     224  AIA                          Anguilla           The Valley
# 7     201  ATG               Antigua and Barbuda         Saint John’s
# 8      33  ARG                         Argentina         Buenos Aires
# 9     140  ARM                           Armenia              Yerevan
# 10    198  ABW                             Aruba           Oranjestad
# 11     55  AUS                         Australia             Canberra
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.loc[df['World Population Percentage'].idxmax(), ['Country/Territory', 'World Population Percentage']]
# Out:
# Country/Territory              China
# World Population Percentage    17.88
# Name: 41, dtype: object

# %%
df[["Country/Territory","World Population Percentage"]].sort_values(by="World Population Percentage",ascending=False).head(3)
# Out:
#     Country/Territory  World Population Percentage
# 41              China                        17.88
# 92              India                        17.77
# 221     United States                         4.24

# %%
df[["Country/Territory","World Population Percentage"]].sort_values(by="World Population Percentage",ascending=True).head(3)
# Out:
#     Country/Territory  World Population Percentage
# 116     Liechtenstein                          0.0
# 103            Jersey                          0.0
# 185        Seychelles                          0.0

# %%
df[["Country/Territory","2022 Population"]].max()
# Out:
# Country/Territory      Zimbabwe
# 2022 Population      1425887337
# dtype: object

# %%
df[["Country/Territory","2022 Population"]].min()
# Out:
# Country/Territory    Afghanistan
# 2022 Population              510
# dtype: object

# %%
df['2022 Population'].mean()
# Out:
# 34074414.70940171

# %%
df["2022 Population"].sum()
# Out:
# 7973413042

# %%
continent=df['Continent'].value_counts().idxmax()
count=df['Continent'].value_counts().max()
print(f"{continent} has {count} countries")
# Out:
# Africa has 57 countries

# %%
df[["Country/Territory","2022 Population"]].max()
# Out:
# Country/Territory      Zimbabwe
# 2022 Population      1425887337
# dtype: object

# %%
df[["Country/Territory","2020 Population"]].max()
# Out:
# Country/Territory      Zimbabwe
# 2020 Population      1424929781
# dtype: object

# %%
df["2022-2020"]=df['2022 Population']-df['2020 Population']
df["2022-2020"].max()
df[["Country/Territory","2022-2020"]].max()
# Out:
# Country/Territory    Zimbabwe
# 2022-2020            20786046
# dtype: object

# %%
df.set_index("Rank",inplace=True)

# %%
df=df.drop(["CCA3"],axis=1)
df
# Out:
#       Country/Territory  Capital  Continent  2022 Population  2020 Population  \
# Rank
# 36                  0.0     89.0        1.0         41128771         38972230
# 138                 1.0    211.0        2.0          2842321          2866849
# 34                  2.0      4.0        0.0         44903225         43451666
# 213                 3.0    150.0        4.0            44273            46189
# 203                 4.0      8.0        2.0            79824            77700
# 42                  5.0    107.0        0.0         35588987         33428485
# 224                 6.0    209.0        3.0            15857            15585
# 201                 7.0    180.0        3.0            93763            92664
# 33                  8.0     43.0        5.0         45510318         45036032
# 140                 9.0    232.0        1.0          2780469          2805608
# 198                10.0    146.0        3.0           106445           106585
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
encode=OrdinalEncoder()

# %%
for i in df.select_dtypes(include=["object"]).columns:
  df[i]=encode.fit_transform(df[[i]])

# %%
for i in df.select_dtypes(include=["object"]).columns:
  print(i,df[i].unique())

# %%
df
# Out:
#       Country/Territory  Capital  Continent  2022 Population  2020 Population  \
# Rank
# 36                  0.0     89.0        1.0         41128771         38972230
# 138                 1.0    211.0        2.0          2842321          2866849
# 34                  2.0      4.0        0.0         44903225         43451666
# 213                 3.0    150.0        4.0            44273            46189
# 203                 4.0      8.0        2.0            79824            77700
# 42                  5.0    107.0        0.0         35588987         33428485
# 224                 6.0    209.0        3.0            15857            15585
# 201                 7.0    180.0        3.0            93763            92664
# 33                  8.0     43.0        5.0         45510318         45036032
# 140                 9.0    232.0        1.0          2780469          2805608
# 198                10.0    146.0        3.0           106445           106585
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 36 to 74
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country/Territory            234 non-null    float64
#  1   Capital                      234 non-null    float64
#  2   Continent                    234 non-null    float64
#  3   2022 Population              234 non-null    int64
#  4   2020 Population              234 non-null    int64
#  5   2015 Population              234 non-null    int64
#  6   2010 Population              234 non-null    int64
#  7   2000 Population              234 non-null    int64
#  8   1990 Population              234 non-null    int64
#  9   1980 Population              234 non-null    int64
#  10  1970 Population              234 non-null    int64
#  11  Area (km²)                   234 non-null    int64
#  12  Density (per km²)            234 non-null    float64
# ...

# %%
df.corr()
# Out:
#                              Country/Territory   Capital  Continent  \
# Country/Territory                     1.000000 -0.027703  -0.042649
# Capital                              -0.027703  1.000000   0.083617
# Continent                            -0.042649  0.083617   1.000000
# 2022 Population                      -0.044589 -0.078016  -0.090415
# 2020 Population                      -0.044706 -0.077126  -0.088144
# 2015 Population                      -0.044745 -0.075373  -0.083488
# 2010 Population                      -0.044699 -0.073601  -0.079227
# 2000 Population                      -0.045543 -0.071453  -0.072063
# 1990 Population                      -0.045633 -0.069952  -0.066962
# 1980 Population                      -0.044613 -0.067360  -0.061749
# 1970 Population                      -0.043454 -0.064576  -0.057658
# Area (km²)                           -0.051993 -0.032602   0.037024
# Density (per km²)                     0.013591 -0.023288  -0.043148
# ...

# %%
for i in df.columns:
  print(i,df[i].nunique())
  print("------------------------")
# Out:
# Country/Territory 234
# ------------------------
# Capital 234
# ------------------------
# Continent 6
# ------------------------
# 2022 Population 234
# ------------------------
# 2020 Population 234
# ------------------------
# 2015 Population 234
# ------------------------
# 2010 Population 234
# ------------------------
# 2000 Population 234
# ------------------------
# 1990 Population 234
# ------------------------
# 1980 Population 234
# ------------------------
# 1970 Population 234
# ------------------------
# Area (km²) 233
# ------------------------
# Density (per km²) 234
# ------------------------
# Growth Rate 180
# ------------------------
# World Population Percentage 70
# ------------------------

# %%
df.columns
# Out:
# Index(['Country/Territory', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')
